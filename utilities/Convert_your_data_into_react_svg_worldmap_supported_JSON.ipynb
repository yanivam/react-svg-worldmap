# %% [markdown]
# #### Dependecies & Defauls

# %%
from difflib import SequenceMatcher
import typing as t

# react-svg-worldmap's country name to short name mapping
COUNTRIES_SHORT_NAME_MAPPING = {'Afghanistan': 'AF', 'Albania': 'AL', 'Algeria': 'DZ', 'Angola': 'AO', 'Argentina': 'AR', 'Armenia': 'AM', 'Australia': 'AU', 'Austria': 'AT', 'Azerbaijan': 'AZ', 'Bahamas': 'BS', 'Bangladesh': 'BD', 'Belarus': 'BY', 'Belgium': 'BE', 'Belize': 'BZ', 'Benin': 'BJ', 'Bhutan': 'BT', 'Bolivia': 'BO', 'Bosnia and Herzegovina': 'BA', 'Botswana': 'BW', 'Brazil': 'BR', 'Brunei Darussalam': 'BN', 'Bulgaria': 'BG', 'Burkina Faso': 'BF', 'Burundi': 'BI', 'Cambodia': 'KH', 'Cameroon': 'CM', 'Canada': 'CA', 'Central African Republic': 'CF', 'Chad': 'TD', 'Chile': 'CL', 'China': 'CN', 'Colombia': 'CO', 'Costa Rica': 'CR', 'Croatia': 'HR', 'Cuba': 'CU', 'Cyprus': 'CY', 'Czech Republic': 'CZ', "Côted'Ivoire": 'CI', 'Dem. Rep. Korea': 'KP', 'Democratic Republic of the Congo': 'CD', 'Denmark': 'DK', 'Djibouti': 'DJ', 'Dominican Republic': 'DO', 'Ecuador': 'EC', 'Egypt': 'EG', 'El Salvador': 'SV', 'Equatorial Guinea': 'GQ', 'Eritrea': 'ER', 'Estonia': 'EE', 'Eswatini': 'SZ', 'Ethiopia': 'ET', 'Falkland Islands': 'FK', 'Fiji': 'FJ', 'Finland': 'FI', 'France': 'FR', 'Gabon': 'GA', 'Georgia': 'GE', 'Germany': 'DE', 'Ghana': 'GH', 'Greece': 'GR', 'Greenland': 'GL', 'Guatemala': 'GT', 'Guinea': 'GN', 'Guinea-Bissau': 'GW', 'Guyana': 'GY', 'Haiti': 'HT', 'Honduras': 'HN', 'Hungary': 'HU', 'Iceland': 'IS', 'India': 'IN', 'Indonesia': 'ID', 'Iran': 'IR', 'Iraq': 'IQ', 'Ireland': 'IE', 'Israel': 'IL', 'Italy': 'IT', 'Jamaica': 'JM', 'Japan': 'JP', 'Jordan': 'JO', 'Kazakhstan': 'KZ', 'Kenya': 'KE', 'Kosovo': 'XK', 'Kuwait': 'KW', 'Kyrgyzstan': 'KG', 'Lao PDR': 'LA', 'Latvia': 'LV', 'Lebanon': 'LB', 'Lesotho': 'LS', 'Liberia': 'LR', 'Libya': 'LY', 'Lithuania': 'LT', 'Luxembourg': 'LU', 'Macedonia': 'MK', 'Madagascar': 'MG', 'Malawi': 'MW', 'Malaysia': 'MY', 'Mali': 'ML', 'Mauritania': 'MR', 'Mexico': 'MX', 'Moldova': 'MD', 'Mongolia': 'MN', 'Montenegro': 'ME', 'Morocco': 'MA', 'Mozambique': 'MZ', 'Myanmar': 'MM', 'Namibia': 'NA', 'Nepal': 'NP', 'Netherlands': 'NL', 'New Caledonia': 'NC', 'New Zealand': 'NZ', 'Nicaragua': 'NI', 'Niger': 'NE', 'Nigeria': 'NG', 'Northern Cyprus': 'CYP', 'Norway': 'NO', 'Oman': 'OM', 'Pakistan': 'PK', 'Palestine': 'PS', 'Panama': 'PA', 'Papua New Guinea': 'PG', 'Paraguay': 'PY', 'Peru': 'PE', 'Philippines': 'PH', 'Poland': 'PL', 'Portugal': 'PT', 'Puerto Rico': 'PR', 'Qatar': 'QA', 'Republic of Korea': 'KR', 'Republic of the Congo': 'CG', 'Romania': 'RO', 'Russia': 'RU', 'Rwanda': 'RW', 'Saudi Arabia': 'SA', 'Senegal': 'SN', 'Serbia': 'RS', 'Sierra Leone': 'SL', 'Slovakia': 'SK', 'Slovenia': 'SI', 'Solomon Islands': 'SB', 'Somalia': 'SO', 'Somaliland': 'SOM', 'South Africa': 'ZA', 'South Sudan': 'SS', 'Spain': 'ES', 'Sri Lanka': 'LK', 'Sudan': 'SD', 'Suriname': 'SR', 'Sweden': 'SE', 'Switzerland': 'CH', 'Syria': 'SY', 'Taiwan': 'TW', 'Tajikistan': 'TJ', 'Tanzania': 'TZ', 'Thailand': 'TH', 'The Gambia': 'GM', 'Timor-Leste': 'TL', 'Togo': 'TG', 'Trinidad and Tobago': 'TT', 'Tunisia': 'TN', 'Turkey': 'TR', 'Turkmenistan': 'TM', 'Uganda': 'UG', 'Ukraine': 'UA', 'United Arab Emirates': 'AE', 'United Kingdom': 'GB', 'United States': 'US', 'Uruguay': 'UY', 'Uzbekistan': 'UZ', 'Vanuatu': 'VU', 'Venezuela': 'VE', 'Vietnam': 'VN', 'Western Sahara': 'EH', 'Yemen': 'YE', 'Zambia': 'ZM', 'Zimbabwe': 'ZW'}

def similarity(a: str, b: str) -> float:
  """Calculates similarity between two strings."""
  return SequenceMatcher(None, a, b).ratio()

# %% [markdown]
# #### Utility functions

# %%
apeda_to_world_map_names_mapping = {}  # Your country name to short name mapping.
progress_index = 0  # For continuing mapping where it stops...

# %%
# apeda_to_world_map_names_mapping: APEDA countries name to world map short names mapping
# COUNTRIES_SHORT_NAME_MAPPING: World map countries mapping

def add_new_apeda_country_name_to_mapping(new_country_name: str) -> None:
  """Adds new country name to your mapping.

  Explanation:
    Whenever it finds a new country name, it will try to find the similar country
    name in library's mapping. If a similar one is found, it will add it directly
    into your mapping.
    If it is not sure, it will show the top 10 similar country name for you to
    choose from.
    If it does not find similar ones, it will ask you to enter the short name.
  
  Args:
    new_country_name: The new country name it founded which is not in the mapping.
  """
  similarity_dict = sorted({s: similarity(new_country_name, s) for s in COUNTRIES_SHORT_NAME_MAPPING.keys()}.items(), key=lambda item: item[1], reverse=True)

  if similarity_dict[0][1] > 0.9:
    _short_name = COUNTRIES_SHORT_NAME_MAPPING[similarity_dict[0][0]]
  elif similarity_dict[0][1] > 0.5:
    print(f'\nTop 10 similar ones: {[(c[0], COUNTRIES_SHORT_NAME_MAPPING[c[0]], c[1]) for c in similarity_dict[:10]]}')
    _short_name = str(input(f'short name for {new_country_name}:'))
  else:
    _short_name = str(input(f'short name for {new_country_name}:'))

  apeda_to_world_map_names_mapping[new_country_name] = _short_name


def convert_countries_string_to_short_names(string: str):
  """Convert your country data into react-svg-worldmap supported mapping
  
  Args:
    string: A long string including country name & values. i.e.
    1	U S A	853,090.00	659,119.00
    2	Germany	261,564.00	454,509.00
    ...
  
  Output:
    It will print JSON equivalent result that you can put directly in a new JSON
    file.
  """
  str_l = string.split('\n')
  results = []
  included_countries = []
  results.append('{\n\t"data": [')

  for s in str_l:
    sl = s.split()
    name = ' '.join(sl[1:-2])

    # If name is not present, add it.
    if name not in apeda_to_world_map_names_mapping:
      add_new_apeda_country_name_to_mapping(name)

    short_name = apeda_to_world_map_names_mapping[name]
    included_countries.append(short_name)
    val = sl[-2].replace(',', '')
    results.append('\t\t{ ' + f'"country": "{short_name}", "value": {val}' + ' },')

  remaining_countries = list(set(COUNTRIES_SHORT_NAME_MAPPING.values()) - set(included_countries))
  for s in remaining_countries:
    results.append('\t\t{ ' + f'"country": "{s}", "value": 0' + ' },')
  
  results[-1] = results[-1][:-1]
  results.append('\t]\n}')

  for r in results:
    print(r)

# %% [markdown]
# #### Example

# %%
# Input source: http://apeda.in/agriexchange/ProductSearch/Major_Imporing_Countries.aspx?mi=major_imp&hscode=6a%2bynF9I77qrXizNX%2byuWXVTPNyZVWiCeDqOqLpEEgABUAuywICTAH8FoC7Er4QLPoD13MOcPsw%3d&hscode1=6a%2bynF9I77o0mk0cmZC8sizFAo0JUygfQYlGZsKEKLhxtcp0XnLrGsMEDuxktFIjh9XP4P%2fHbtNJx4AWyXPyaRBgfKznQR0tNgwtYpPv9IYO7rcbNftLFfVQCfEY%2f4ioRob%2fmBgB%2bwoCVh%2bFdSi8dGOp6c7EgKMB94ecLmtmF%2bk%3d
your_input_string = """1	U S A	853,090.00	659,119.00
2	Germany	261,564.00	454,509.00
3	France	173,242.00	276,884.00
4	NETHERLAND	241,806.00	276,156.00
5	Russia	239,432.00	228,585.00
6	U K	165,979.00	195,492.00
7	Poland	138,717.00	181,797.00
8	Italy	118,957.00	138,699.00
9	Canada	66,071.00	127,782.00
10	SAUDI ARAB	145,174.00	108,396.00
11	CZECH REPUBLIC	81,392.00	106,685.00
12	U ARAB EMTS	135,947.00	97,052.00
13	Japan	46,783.00	95,031.00
14	Korea RP	40,743.00	78,950.00
15	Austria	40,707.00	76,958.00
16	Romania	62,859.00	71,075.00
17	Belgium	37,289.00	62,727.00
18	Switzerland	31,603.00	62,152.00
19	Spain	54,501.00	61,678.00
20	SLOVAK REP	42,857.00	58,368.00
21	Ukraine	65,425.00	57,644.00
22	Portugal	36,127.00	40,652.00
23	Sweden	31,454.00	40,168.00
24	Philippines	30,668.00	39,393.00
25	Hong Kong	31,198.00	37,663.00
26	Serbia	29,658.00	31,640.00
27	Denmark	17,539.00	29,807.00
28	Bulgaria	32,750.00	29,681.00
29	Hungary	22,605.00	29,080.00
30	Indonesia	11,614.00	28,062.00
31	Greece	25,539.00	27,884.00
32	Malaysia	27,154.00	26,543.00
33	Australia	6,110.00	25,482.00
34	Kuwait	31,985.00	25,361.00
35	Norway	10,807.00	20,641.00
36	Croatia	16,198.00	19,054.00
37	Jordan	14,789.00	18,996.00
38	Ireland	11,297.00	18,217.00
39	Slovenia	14,683.00	17,056.00
40	Qatar	17,590.00	16,689.00
41	Singapore	12,358.00	15,874.00
42	China P RP	10,697.00	15,757.00
43	Finland	10,858.00	14,738.00
44	Belarus	12,943.00	13,977.00
45	Lithuania	11,309.00	13,780.00
46	Azerbaijan	12,476.00	12,092.00
47	BOSNIA-HRZGOVIN	13,294.00	9,833.00
48	Chile	10,853.00	9,043.00
49	Latvia	6,588.00	7,328.00
50	Macedonia	9,186.00	6,343.00
51	Moldova	5,129.00	5,899.00
52	Kazakhstan	6,836.00	5,739.00
53	Luxembourg	1,924.00	5,111.00
54	Thailand	6,827.00	5,035.00
55	New Zealand	1,443.00	3,960.00
56	Albania	5,097.00	3,693.00
57	Estonia	2,670.00	3,473.00
58	SERBIA MONTNGRO	3,389.00	3,406.00
59	Argentina	3,392.00	3,053.00
60	Armenia	3,823.00	2,847.00
61	Brazil	2,386.00	2,471.00
62	Georgia	5,334.00	2,420.00
63	Cyprus	1,715.00	1,930.00
64	Macao	1,321.00	1,838.00
65	Turkey	3,304.00	1,716.00
66	Ecuador	4,948.00	1,679.00
67	Other Asia, nes	867.00	1,612.00
68	BRUNEI	1,028.00	1,556.00
69	DOMINIC REP	1,218.00	1,507.00
70	Iceland	1,115.00	1,442.00
71	Mauritius	1,683.00	1,400.00
72	Aruba	761.00	1,277.00
73	Mexico	1,202.00	1,263.00
74	KYRGHYZSTAN	1,402.00	1,153.00
75	Malta	697.00	1,049.00
76	Nigeria	1,227.00	962.00
77	Costa Rica	767.00	952.00
78	Uruguay	1,140.00	905.00
79	Namibia	984.00	869.00
80	Paraguay	4,470.00	787.00
81	Barbados	721.00	700.00
82	BOLIVIA	2,442.00	676.00
83	South Africa	2,012.00	660.00
84	Bermuda	292.00	620.00
85	Kenya	742.00	604.00
86	Botswana	552.00	595.00
87	El Salvador	2,374.00	528.00
88	Uzbekistan	686.00	483.00
89	Seychelles	140.00	446.00
90	Ethiopia	1,275.00	407.00
91	Lebanon	511.00	309.00
92	Guatemala	167.00	213.00
93	Eswatini	312.00	169.00
94	Mozambique	141.00	155.00
95	Colombia	424.00	151.00
96	Lesotho	199.00	147.00
97	Nicaragua	1,006.00	145.00
98	VIETNAM SOC REP	106.00	136.00
99	Zambia	191.00	101.00
100	EGYPT A RP	75.00	97.00"""

# %%
convert_countries_string_to_short_names(your_input_string)
# Out:
# {
# 	"data": [
# 		{ "country": "US", "value": 853090.00 },
# 		{ "country": "DE", "value": 261564.00 },
# 		{ "country": "FR", "value": 173242.00 },
# 		{ "country": "NL", "value": 241806.00 },
# 		{ "country": "RU", "value": 239432.00 },
# 		{ "country": "GB", "value": 165979.00 },
# 		{ "country": "PL", "value": 138717.00 },
# 		{ "country": "IT", "value": 118957.00 },
# 		{ "country": "CA", "value": 66071.00 },
# 		{ "country": "SA", "value": 145174.00 },
# 		{ "country": "CZ", "value": 81392.00 },
# 		{ "country": "AE", "value": 135947.00 },
# 		{ "country": "JP", "value": 46783.00 },
# 		{ "country": "KR", "value": 40743.00 },
# 		{ "country": "AT", "value": 40707.00 },
# 		{ "country": "RO", "value": 62859.00 },
# 		{ "country": "BE", "value": 37289.00 },
# 		{ "country": "CH", "value": 31603.00 },
# 		{ "country": "ES", "value": 54501.00 },
# 		{ "country": "SK", "value": 42857.00 },
# 		{ "country": "UA", "value": 65425.00 },
# 		{ "country": "PT", "value": 36127.00 },
# ...
